# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5], [0.118, 0.299, 0.511, 0.760,1.014],'-bo',label='Real')
plt.plot([1, 2, 3, 4, 5], [0.394, 1.065, 1.858, 2.761,3.755],'-ro',label='User')
plt.plot([1, 2, 3, 4, 5], [0.016, 0.031, 0.044, 0.060,0.079],'-go',label='Sys')
plt.title('Multi Processing')
plt.ylabel('Time for execution (in msec) ')
plt.xlabel('n ( in 10^6)')
plt.legend(loc = 'best')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5], [0.121, 0.292, 0.497, 0.746,1.002],'-ro',label='multi thread')
plt.plot([1, 2, 3, 4, 5], [0.402, 1.055, 1.849, 2.770,3.774],'-ro',label='multi thread')
plt.plot([1, 2, 3, 4, 5], [0.008, 0.010, 0.012, 0.020,0.024],'-ro',label='multi thread')
plt.title('Multi Threading')
plt.ylabel('Time for execution (in sec)')
plt.xlabel('n ( in 10^6)')
plt.legend(loc = 'best')
plt.show()

# %%
real	0m0.121s
user	0m0.402s
sys	0m0.008s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 2000000 10

real	0m0.292s
user	0m1.055s
sys	0m0.008s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 3000000 10

real	0m0.497s
user	0m1.849s
sys	0m0.012s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 4000000 10

real	0m0.746s
user	0m2.770s
sys	0m0.020s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 5000000 10

real	0m1.002s
user	0m3.774s
sys	0m0.024s

# %%
real	0m0.118s
user	0m0.394s
sys	0m0.016s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 2000000 10

real	0m0.299s
user	0m1.065s
sys	0m0.031s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 3000000 10

real	0m0.511s
user	0m1.858s
sys	0m0.044s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 4000000 10

real	0m0.760s
user	0m2.761s
sys	0m0.060s
abhi@incident:~/Desktop/Sem 5/OS/asn2$ time ./a.out 5000000 10

real	0m1.014s
user	0m3.755s
sys	0m0.079s
